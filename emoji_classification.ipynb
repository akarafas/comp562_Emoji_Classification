# %%
tweetFile = open("emojitweets-01-04-2018.txt", encoding="utf8")
number_of_lines = 5
for i in range(number_of_lines):
    line = tweetFile.readline()
    print(line)
# Out:
# Squad arriving for Game 2 🚀
#
# Dude is like 5’8 140 pounds his dick was long and strong(always the little dudes carrying the 🍆) 🤪🙃
#
# FOLLOWERS👇
#
# I CANT BREATIUHW 💀💀💀
#
# 2️⃣4️⃣ hours 'til our schedule drops!
#
# NEW || Zach &amp; Jack at Limelight tonight! (April 17) ©️nvmbesson
#
# I’m live at Milk Boy studio the home of  making some hits 💪🏾
#
# I am SO scared of birds🤧
#
# That’s me 😂😂😂😂😂😂
#
# My heart is so full rn 💖💖
#
# This is one of my favorite songs to sing in this episode ❤️
#
# Took my goat to get groomed for the first time 😂
#
# NEW || Zayn in NYC today! (Yes its outside G’s apartment if you’re wondering) (©️Gettyimages)
#
# this summer i’m living my BEST life &amp; i mean that🤪🤪🤪🤪🤪🤪💯
#
# 💰🚶🏻‍♀️🚶🏻‍♀️🚶🏻‍♀️💃🏻👠 Let em know 👏🏾
#
# this summer i’m living my BEST life &amp; i mean that🤪🤪🤪🤪🤪🤪💯
#
# 🔔 [ MTV LATIN AMERICA AWARDS ] 🕙 as of 1:00 - 2:00 AM KST 🕑 👉 KPOP REVOLUTION 1. : 130.7k 🏃 2. G…
#
# army, follow who retweet this 🔥
#
# Perfect da Ally Brooke e Topic pf pf 🙏🏻💞💞
#
# RT if you wanna pump me full of your cum 💦
#
# JULES!!!!!!☠️☠️☠️
#
# Look at the reactions from Jcole’s listening party😭
#
# WONDERFUL!!!!!!!!!!!!!!!!!!!!!! 💁🏼‍♀️👏✌️
#
# Look at the reactions from Jcole’s listening party😭
#
# Aver 🤔
#
# 🔔  🔔 [ 8:00 - 9:00 AM KST ] 1. : 54.5K+ ⚠ 2. G : 21.5K+ Please widen the gap!! T…
#
# 🌟Get this tweet to 399 replies!🌟 ➡We are running behind in this category!⚠👇
#
# Public play 🔥
#
# "OMG!!😍😂😻🐶😻😍 Jump altogether 🌹💕😂😻🐶😻😂💕🌹 This is unbelievable..😂😻🐶😻😂"
#
# 😂😂😂😭😭😭😭 YA THINK. Imma need some back story now
#
# 💄 The Most Popular Dating Site 💋 Free online sex dating 🔥 🔥 🔥 …
#
# NCT is back at it again with 'Black on Black' MV! [] 🎶🎶🎶🎶🎶🎶🎶🎶🎶
#
# Just a sip. 😆
#
# Ricochets theme song gives me that "fighting a raid boss in destiny/destiny2 vibe" 😂
#
# i got you bby❤️😉
#
# 🙏Thank you for withdrawing your endorsement of GOP state senate candidate Julie Killian, who attacked
#
# Kylie Jenner shares a video of baby Stormi 👼🏽
#
# That’s awesome! Plus you’re a Meredith Angel!!😇🤗😉
#
# Fancy huh? is Rocking the crudités game with fresh veggies from 🙌🏼 Try adding fennel…
#
# Fancy huh? is Rocking the crudités game with fresh veggies from 🙌🏼 Try adding fennel…
#
# if there are any eligible bachelors, i’m accepting prom date applications. hmu. 🙏🏽
# Dost 😁💚
#
# BF definitely since he thinks he’s the star of the show 🙄
#
# army, follow who retweet this 🔥
#
# When you realize your 5 page paper is due at midnight 🙃
#
# When yo name hold weight they gone talk about you 💯
#
# He’s a great DJ. I seen him on Facebook Live. 😃
#
# in the mood for 🍦🍧
#
# Nice win by the Girls Softball Team over St. Dom’s today!   ⚾️
#
# That’s the plan love 😘💙
#
# BF definitely since he thinks he’s the star of the show 🙄
#
# This is the sweetest baby elephant .... I just had to share it 💛 Tell me if you love this as…
#
# Listen to Lil'Chinoo x Thoughts 2 Myself by NBR 🎒  on
#
# These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…
#
# Ohhhhh see you on  mami 💃🏻
#
# this her thing and favorite song rn lmaooo 😭💖
#
# When yo name hold weight they gone talk about you 💯
#
# This is why I don’t reply to people on Facebook. Y’all listen to this 😂🤦🏾‍♀️
#
# the presenter just wanted her to shut up 😂😭
#
# These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…
#
# A hot shower before some hot fun with Adam later   - let’s play 😈😘 G x
#
# 2nd free title update is here! Behold the majestic Kulve Taroth. ✨
#
# Never forget. 😤
#
# Their doing this because of the globalist sheep 🐑    of…
#
# WE ALL OWE LLYOD AN APOLOGY!! Cos he actually won! Not gonna be so forgiving on the accent tho! 🤣
#
# These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…
#
# Prom is gonna be a breeze 😁
#
# Oh you know I do!!!👅👅👅

# %%
negativeEmojis = ['🤐', '😟', '😩', '🙃', '😒', '😤', '😫', '👎', '🤔', '😅', '😓', '😭', '🤧', '😈', '🙁','😪', '😴', '☠️', '💀', '💩', '🙀', '😱', '🙄', '😡',
'👊', '😾', '😣', '😔','😮', '😶', '😐', '🤢', '😷','🤥', '👿','😯', '😬', '👻', '🖕', '☹️', '😦', '😳', '😨', '🤒', '🤕', '😑', '😵', '😥', '😞', '😿', '😢','😕',
'😖', '😰']
positiveEmojis = ['😋', '💛', '😉', '✌️', '💕', '👍', '😎', '😜', '😝', '😛', '💖', '😼', '😏', '😺', '😃','😸', '😄', '🙂', '🤣', '💞', '😌', '🙌', '💜', '🙏', '👌', '🤓', '🤑','👄', '😆', '😙', '😘', '😚','😽', '😗', '💋', '😹', '😂', '😇', '🤗', '💗', '💓', '😻', '😍', '❤️', '🤝', '😀', '😁', '💚', '💝', '🤤','💘', '🤞', '🤠', '👏', '😊', '💙', '🖤', '💯', '🤪']
print(negativeEmojis)
print(positiveEmojis)
print(len(negativeEmojis))
print(len(positiveEmojis))
# Out:
# ['🤐', '😟', '😩', '🙃', '😒', '😤', '😫', '👎', '🤔', '😅', '😓', '😭', '🤧', '😈', '🙁', '😪', '😴', '☠️', '💀', '💩', '🙀', '😱', '🙄', '😡', '👊', '😾', '😣', '😔', '😮', '😶', '😐', '🤢', '😷', '🤥', '👿', '😯', '😬', '👻', '🖕', '☹️', '😦', '😳', '😨', '🤒', '🤕', '😑', '😵', '😥', '😞', '😿', '😢', '😕', '😖', '😰']
# ['😋', '💛', '😉', '✌️', '💕', '👍', '😎', '😜', '😝', '😛', '💖', '😼', '😏', '😺', '😃', '😸', '😄', '🙂', '🤣', '💞', '😌', '🙌', '💜', '🙏', '👌', '🤓', '🤑', '👄', '😆', '😙', '😘', '😚', '😽', '😗', '💋', '😹', '😂', '😇', '🤗', '💗', '💓', '😻', '😍', '❤️', '🤝', '😀', '😁', '💚', '💝', '🤤', '💘', '🤞', '🤠', '👏', '😊', '💙', '🖤', '💯', '🤪']
# 54
# 59

# %%
# tweetFile = open("emojitweets-01-04-2018.txt", encoding="utf8")
# need to go through and add labels
labeledTweetMatrix = []
tweets_x = []
tweets_y = []
tweetFile = open("emojitweets-01-04-2018.txt", encoding="utf8")
for i in tweetFile:
    line = tweetFile.readline()
    if any(emoji in line for emoji in positiveEmojis):
        labeledTweetMatrix.append([line.rstrip("\n"), 1])
        tweets_x.append(line.rstrip("\n"))
        tweets_y.append(1)
    elif any(emoji in line for emoji in negativeEmojis):
        # labelVector[i] = -1
        labeledTweetMatrix.append([line.rstrip("\n"), -1])
        tweets_x.append(line.rstrip("\n"))
        tweets_y.append(-1)

    # this will assign all with a +1 emoji 1 and anything else (negative or 0 sentiment) -1
print(len(labeledTweetMatrix))
print(len(tweets_x))
print(len(tweets_y))
# print(labeledTweetMatrix[5000])
# Out:
# 5941474

# %%
for i in range(5):
    # print(labeledTweetMatrix[i])
    print(tweets_x[i])
    print(tweets_y[i])
# Out:
# ['Dude is like 5’8 140 pounds his dick was long and strong(always the little dudes carrying the 🍆) 🤪🙃', 1]
# ['I CANT BREATIUHW 💀💀💀', -1]
# ['I am SO scared of birds🤧', -1]
# ['My heart is so full rn 💖💖', 1]
# ['Took my goat to get groomed for the first time 😂', 1]
# ['this summer i’m living my BEST life &amp; i mean that🤪🤪🤪🤪🤪🤪💯', 1]
# ['this summer i’m living my BEST life &amp; i mean that🤪🤪🤪🤪🤪🤪💯', 1]
# ['Look at the reactions from Jcole’s listening party😭', -1]
# ['Look at the reactions from Jcole’s listening party😭', -1]
# ['😂😂😂😭😭😭😭 YA THINK. Imma need some back story now', 1]
# ['Ricochets theme song gives me that "fighting a raid boss in destiny/destiny2 vibe" 😂', 1]
# ['🙏Thank you for withdrawing your endorsement of GOP state senate candidate Julie Killian, who attacked', 1]
# ['That’s awesome! Plus you’re a Meredith Angel!!😇🤗😉', 1]
# ['Fancy huh? is Rocking the crudités game with fresh veggies from 🙌🏼 Try adding fennel…', 1]
# ['My practice teacher don’t know how happy she made me today eh 😭 like I can’t stop give God thanks for her ❤️', 1]
# ['If she hating, tell that bitch to let it gooooooo 🤣😘✌🏽', 1]
# ['Happy Birthday 🎊❤️', 1]
# ['I want nothing but the best for daddy 🤞🏽❤️', 1]
# ['This is the sweetest baby elephant .... I just had to share it 💛 Tell me if you love this as…', 1]
# ['These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…', 1]
# ['this her thing and favorite song rn lmaooo 😭💖', 1]
# ['This is why I don’t reply to people on Facebook. Y’all listen to this 😂🤦🏾\u200d♀️', 1]
# ['These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…', 1]
# ['These Black Women listening to Taylor Swift’s cover of “September” by Earth, Wind, and Fire is SENDING ME 😭😂😭😂😭😂😭 http…', 1]
# ['LMFAOLOOL WHY WAS IT SCREAMING 😭😭😭😭😭😭😭😭', -1]
# ['the only promposal ive seen from the K 🤣', 1]
# ['[Pls RT💓] Thank you for 4800 followers🎉 Please join our Free Giveaway event and good luck😊 📝Details in poster', 1]
# ['Dad &amp; his mini-mes 🐶🐶🐶💗', 1]
# ['yet another reason why y’all disgust me😂 foolery.', 1]
# ['💄 The Most Popular Dating Site 💋 Free online sex dating 🔥 🔥 🔥 …', 1]
# ["Ok I'm gna stop smokin stoges. Fr this time. After this last pack tho 😂😂", 1]
# ['I just wrote A WHOLE FRICKIN NOVEL in the dms to and it didn’t send triggered 😂', 1]
# ['Damn 🙏🏻🙏🏻 Thoughts and prayers with the Popovich family 🙏', 1]
# ['🤔 no way 😱', -1]
# ['We can do this, ARMYs! 🙏', 1]
# ['when kansas city wasn’t enough 💛.', 1]
# ['Wow😍😍 Her voice🎤', 1]
# ['🤣 mad mean 😩', 1]
# ['We literally drive eachother crazy..but only cause were crazy about eachother😩🤣❤️', 1]
# ['Alright that’s enough, hand North the phone 😂', 1]
# ['Y’all. My sister is psychotic. Once you think it can’t get worse, it does 😂😂😂😂', 1]
# ['Love is the healer 💜', 1]
# ['Her laugh so cute😍😍😫', 1]
# ['🙏🏽 for Pop.', 1]
# ['this is what the world map sounds like on the piano😮', -1]
# ['Everyone vote for my girl Jackie! 😍😍  I just voted for on', 1]
# ['Iiyak yan one of this days..😂😅', 1]
# ['A Quiet Place 😱📽 (@ Avalon Theater for A Quiet Place in Milwaukee, WI)', -1]
# ['"  storycon ❤️❤️ "', 1]
# ['Nic REEEEMIXX ❤️❤️❤️ Ayo, I been on, BITCH YOU BEEN GONE, what’s the album on? NOT MY IPHONE! 💥🤬 nicki…', 1]
# ['Congratulations 🎉❤️', 1]
# ['I don’t care who drops what or when! We’re climbing the chart or we’re going down swinging HARD! 😈🔥🤘🏽', -1]
# ['My family ain’t shit 😂', 1]
# ['Garden Burgers are my go to for lunch and dinner! Healthy eating for life!  ❤️', 1]
# ['Thoughts and prayers with the Popovich family 🙏', 1]
# ['"Kill your darlings" ... maybe I didn\'t do that right😕.', -1]
# ['No wonder the clothes looked familiar ~ 😂😂😂', 1]
# ['i look so much better with dark hair but when I have my dark hair I miss my blonde hair... 😩', -1]
# ["Go on Imran! 👊 It's okay folks, Rana is safe now! Who needs a hug? ❤️ Be a part of", 1]
# ['There be hella cute niggas that work at my moms job, I told her to pmoooo and she said most of the cuties here are gay..🙂😐I’m sadddd😒', 1]

# %%
import matplotlib.pyplot as plt
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Positive', 'Negative'
sizes = [len(positiveEmojis), len(negativeEmojis)]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')
fig1, ax1 = plt.subplots()
colors = ['lightcoral', 'lightskyblue']
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Comparison of positive and negative emojis in our library')
plt.show()

# %%
labels = 'Positive', 'Negative'
# go through labeledTweetMatrix and tally positive sentiment, neg just do len(total) - pos
count = 0
negativeCount = 0
for tweet in labeledTweetMatrix:
    if tweet[1] == 1:
        count += 1
    if tweet[1] == -1:
        negativeCount += 1
sizes = [count, negativeCount]
explode = (0, 0.1)  # only "explode" the 2nd slice
fig1, ax1 = plt.subplots()
colors = ['lightcoral', 'lightskyblue']
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Comparison of positive and negative sentiment tweets')
plt.show()

# %%
# need to preprocess
import nltk                                # Python library for NLP
import preprocessor as p
import random                              # pseudo-random number generator
nltk.download('stopwords')
import re                                  # library for regular expression operations
import string                              # for string operations
from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import TweetTokenizer   # module for tokenizing strings
def tokenize(tweet):
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
    return tweet_tokens
def removeStopWords(tweet_tokenz):
    stopwords_english = stopwords.words('english')
    stopwords_english.extend(['rt', 'fav'])
    tweets_clean = []
    for word in tweet_tokenz:
        if (word not in stopwords_english and word not in string.punctuation):
            tweets_clean.append(word)
    return tweets_clean
def stemmingTweet(tweet):
    stemmer = PorterStemmer()
    tweets_stem = []
    for word in tweet:
        stem_word = stemmer.stem(word)
        tweets_stem.append(stem_word)
    return tweets_stem
def preprocess(tweet):
    tweet.lower()
    p.set_options(p.OPT.NUMBER, p.OPT.SMILEY)
    tweet = p.clean(tweet)
    return stemmingTweet(removeStopWords(tokenize(tweet)))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\akarafas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# example of preprocessing
tweet = labeledTweetMatrix[0][0]
newtweet = preprocess(tweet)
print(tweet)
print(newtweet)
# preprocess entire matrix
for i in range(len(labeledTweetMatrix)):
    processedTweet = preprocess(labeledTweetMatrix[i][0])
    labeledTweetMatrix[i][0] = processedTweet
for i in range(5):
    print(labeledTweetMatrix[i])
# Out:
# Dude is like 5’8 140 pounds his dick was long and strong(always the little dudes carrying the 🍆) 🤪🙃
# ['dude', 'like', '’', '8', 'pound', 'dick', 'long', 'strong', 'alway', 'littl', 'dude', 'carri', '🍆', '🤪', '🙃']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-70f09762b1a5> in <module>
#       6 # preprocess entire matrix
#       7 for i in labeledTweetMatrix:
# ----> 8     processedTweet = preprocess(labeledTweetMatrix[i][0])
#       9     labeledTweetMatrix[i][0] = processedTweet
#      10 for i in range(5):
#
# TypeError: list indices must be integers or slices, not list

# %%
# time for logistic regression
# goal: predict whether a tweet has a positive or negative sentiment based on emojis
